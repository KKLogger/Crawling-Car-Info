# %%
import requests as req
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.action_chains import ActionChains
import pyperclip

ID ='crawling@spiderkim.com'
PW ='Qwert600!'
driver = webdriver.Chrome('./carInfo/carInfo/chromedriver.exe')
driver.maximize_window()
driver.get('https://www.kbchachacha.com/public/login.kbc')

# %%
driver.find_element_by_xpath('//*[@id="divTabSns"]/div/ul/li[4]/a/span').click()
time.sleep(1)

# %%
driver.window_handles
# Out:
# ['CDwindow-77FEB336DC3E0E450034CBB9AFAE1AE2',
#  'CDwindow-D31AACDAF640FC9FADECF5F0860E8B71']

# %%
driver.switch_to.window(driver.window_handles[1])

# %%
driver.find_element_by_xpath('//*[@id="identifierId"]')
pyperclip.copy(ID)
ActionChains(driver).key_down(Keys.CONTROL).send_keys('v').key_up(Keys.CONTROL).perform()
driver.find_element_by_xpath('//*[@id="identifierNext"]/div/button/div[2]').click()
time.sleep(3)

# %%
driver.switch_to.window(driver.window_handles[0])
time.sleep(1)

# %%
driver.find_element_by_xpath('//*[@id="password"]/div[1]/div/div[1]/input')
pyperclip.copy(PW)
ActionChains(driver).key_down(Keys.CONTROL).send_keys('v').key_up(Keys.CONTROL).perform()
driver.find_element_by_xpath('//*[@id="passwordNext"]/div/button/div[2]').click()
time.sleep(5)

# %%
driver.find_element_by_xpath('//*[@id="intro01"]/div/div/div[2]/button').click()
time.sleep(1)

# %%
driver.find_element_by_xpath('//*[@id="layerMainPopup"]/div[2]/div/button').click()

# %%
url = 'https://www.kbchachacha.com/public/car/detail.kbc?carSeq=20788755'

# %%
response = requests.get(url)
soup = bs(response.text,'lxml')
car_price = soup.find('div',{'class':'car-buy-price'}).find('div').find('strong').text
print(car_price)
# Out:
# 980만원

# %%
import requests 
from bs4 import BeautifulSoup as bs


headers= {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language':'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Content-Length': '50',
    'Content-Type': 'application/x-www-form-urlencoded',
    # 'Cookie': WMONID=z6cBryAtOLd; C_PC_LOGIN_TAB=031100; TR10062602448_t_uid=52525555018139668.1603068273787; TR10062602448_t_if=15.0.0.0.null.null.null.0; _ga=GA1.2.1532855553.1603068274; _gid=GA1.2.1042113004.1603068274; JSESSIONID=imnDBdaUtpfKfwyppCeTfpew8SUTXrw5ZkwiizsmhOinuRK3VqWIZ4nw4V1Ga8li.cGNoYWFwbzFfZG9tYWluL0NBUjNBUF9zZXJ2ZXIyX2Nz; FIRST_APPROCH=y; cha-cid=5b6ee6b1-662d-4862-8931-58e1d23dd87f; recent-visited-car=20691996; page-no-action-count=1; car-keyword-code=1462385267421239003%3A2; _gat_UA-78571735-4=1; TR10062602448_t_sst=52525067400001139.1603068354675
    'Host': 'www.kbchachacha.com',
    'Origin': 'https://www.kbchachacha.com',
    'Referer': url,
    'Sec-Fetch-Dest': 'iframe',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36',
}
datas = {
    'layerId': 'layerCarHistoryInfo',
    'carHistorySeq': carHistorySeq
}
response = requests.post('https://www.kbchachacha.com/public/layer/car/history/info.kbc',headers = headers, data=datas)
response
# Out:
# <Response [200]>

# %%
soup = bs(response.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="KB차차차 공식 홈페이지, 최다 중고차 매물 등록대수 1위! 12만대, 중고차 AI시세" name="description"/>
# <title>KB차차차 - 국내 최다 중고차 매물 등록대수 1위! 12만대</title>
# <link href="/favicon.ico" refl="shortcut icon" type="image/x-icon"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <script language="javascript">
# 	var IMAGE_HOST = "https://img.kbchachacha.com";
# </script>
# <link href="/vendor/jquery-ui/v1.12.1/jquery-ui.min.css" rel="stylesheet"/>
# <link href="/vendor/owlCarousel2/v2.3.4/assets/owl.carousel.min.css" rel="stylesheet"/>
# <link href="/vendor/select2/v4.0.2/css/select2.min.css" rel="stylesheet"/>
# <link href="/css/style-ed8ff8f83256a97bb57b7b7ee714a754.css" rel="stylesheet"/>
# <link href="/css/common-4693cfcca637462c25bf092d66bf595b.css" rel="stylesheet"/>
# <link href="/css/custom-8ab570fc5c7a0d92bd22e74763fc9d91.css" rel="stylesheet"/>
# ...

# %%
hide_list =soup.find('ul',{'class':'hide-list'}).find_all('span',{'class':'txt'})
for txt in hide_list:
    print(txt.text.strip())
# Out:
# 없음
# 없음
# 없음
# 없음
# 2회/681,228원
# 2회/1,970,080원
# 2회
# 없음

# %%
# Out:
# <Response [200]>

# %%
# Out:
# '22766411'

# %%
import json
dict = {'안':'녕'}
with open ('j.json', 'w',encoding='utf-8-sig') as file:
    file.write(json.dumps(dict,ensure_ascii=False))
